# %% [markdown]
# # Exercise 1
#
# The following data URL should yield a JSON array containing just one member object.
# By substituting limit=1 with limit=all you should get an array with 12856
# members.
#
# Task: By using just one HTTP request for each program execution, create a
# list of all unique expeditions as newline separated JSON (ndjson), sorted by
# date of first sampling.
#
# Each line should contain the expedition code, the first and last sampling dates
# (iso-formatted), the programs connected with the expedition, and the expedition
# vessel/conveyance. (You may assume that programs and vessels are constant for
# each expedition).
#
# You may choose the programming language of your liking to complete the exercise.
# The resulting program should be runnable from the command line on a linux system
# (x86_64) and receive its input from STDIN. Please provide a covenience shell
# script or a command-line one-liner to invoke your code.

# %% [markdown]
# Imports

# %%
import requests
import pandas as pd
import io

# %% [markdown]
# Build url:

# %%
base_url = 'https://api.npolar.no/marine/biology/sample/'
fields = [ 'expedition', 'utc_date', 'programs', 'conveyance']
limit = 'all'
out_format = 'json'
variant = 'array'

def build_url():
    return f"{base_url}?q=&fields={','.join(fields)}&limit={limit}&format={out_format}&variant={variant}";

print(build_url())
# Out:
# https://api.npolar.no/marine/biology/sample/?q=&fields=expedition,utc_date,programs,conveyance&limit=all&format=json&variant=array

# %% [markdown]
# Fetch data:

# %%
url = build_url();
url_data = requests.get(url).content
data = pd.read_json(io.StringIO(url_data.decode('utf-8')))
print(data.shape)
data.head()
# Out:
# (12856, 4)
#        conveyance                  expedition           programs  \
# 0  Helmer Hanssen  2012-01-EXPEDITION-MISSING  [BIO-8510 ARCTOS]
# 1       Jan Mayen             Fellestokt-1999       [Fellestokt]
# 2           Lance                ICE-BAR 1995          [ICE-BAR]
# 3       Jan Mayen             Fellestokt-1999       [Fellestokt]
# 4  Helmer Hanssen  2012-01-EXPEDITION-MISSING  [BIO-8510 ARCTOS]
#
#                utc_date
# 0  2012-01-17T21:33:00Z
# 1  1999-10-05T20:20:00Z
# 2  1995-06-21T22:00:00Z
# 3  1999-10-06T14:40:00Z
# 4  2012-01-12T22:36:00Z

# %%
len(data.expedition.unique())
# Out:
# 56

# %%
data_mod = data.rename(columns={'utc_date': 'first_sampling_date'})
data_mod['last_sampling_date'] = data_mod['first_sampling_date']
data_mod.head()
# Out:
#        conveyance                  expedition           programs  \
# 0  Helmer Hanssen  2012-01-EXPEDITION-MISSING  [BIO-8510 ARCTOS]
# 1       Jan Mayen             Fellestokt-1999       [Fellestokt]
# 2           Lance                ICE-BAR 1995          [ICE-BAR]
# 3       Jan Mayen             Fellestokt-1999       [Fellestokt]
# 4  Helmer Hanssen  2012-01-EXPEDITION-MISSING  [BIO-8510 ARCTOS]
#
#     first_sampling_date    last_sampling_date
# 0  2012-01-17T21:33:00Z  2012-01-17T21:33:00Z
# 1  1999-10-05T20:20:00Z  1999-10-05T20:20:00Z
# 2  1995-06-21T22:00:00Z  1995-06-21T22:00:00Z
# 3  1999-10-06T14:40:00Z  1999-10-06T14:40:00Z
# 4  2012-01-12T22:36:00Z  2012-01-12T22:36:00Z

# %% [markdown]
# Group by expeditions:

# %%
expeditions = data_mod.groupby('expedition', as_index=False).agg({
    'conveyance': min,
    'programs': min,
    'first_sampling_date': min,
    'last_sampling_date': max
}).sort_values('first_sampling_date')
expeditions.tail(10)
# Out:
#                     expedition       conveyance           programs  \
# 48                      SANA09  Viking Explorer                NaN
# 10             Alkekonge-2009b  Viking Explorer  [Alkekonge, MOSJ]
# 11              Alkekonge-2010            Lance  [Alkekonge, MOSJ]
# 29                     ICE2010            Lance          [ICE ECO]
# 30                     ICE2011            Lance          [ICE ECO]
# 7   2011-04-EXPEDITION-MISSING            Lance          [ICE ECO]
# 36                    MOSJ2012            Lance             [MOSJ]
# 31                     ICE2012            Lance              [ICE]
# 8   2012-01-EXPEDITION-MISSING   Helmer Hanssen  [BIO-8510 ARCTOS]
# 37                    MOSJ2013            Lance          [ICE ECO]
#
#      first_sampling_date    last_sampling_date
# 48  2009-07-21T12:00:00Z  2009-07-27T12:00:00Z
# 10  2009-07-21T15:15:00Z  2009-07-28T15:05:00Z
# 11  2010-07-17T12:50:00Z  2010-07-26T04:40:00Z
# 29  2010-08-17T22:25:00Z  2010-08-30T08:00:00Z
# 30  2011-04-27T20:38:00Z  2011-05-14T04:20:00Z
# 7   2011-04-29T15:00:00Z  2011-04-29T15:00:00Z
# 36  2011-07-13T14:00:00Z  2012-07-21T11:00:00Z
# 31  2011-07-26T20:30:00Z  2013-07-30T07:59:59Z
# 8   2012-01-12T02:28:00Z  2012-01-18T21:42:59Z
# 37  2013-07-23T00:00:00Z  2017-02-16T00:00:00Z

# %% [markdown]
# Remove NaNs:

# %%
def fillNaNsWithList(df, col):
    for row in df.loc[df[col].isnull(), col].index:
        df.at[row, col] = []
    return df
expeditions = fillNaNsWithList(expeditions, 'programs')
expeditions = expeditions.fillna({'conveyance': '', 'first_sampling_date': '', 'last_sampling_date': ''})
expeditions
# Out:
#                     expedition          conveyance  \
# 27                ICE-BAR 1995               Lance
# 12                BIODAFF-1996             Oceania
# 28                ICE-BAR 1996               Lance
# 13                BIODAFF-1997             Oceania
# 52             UNIS-AB310-1998           Jan Mayen
# 33                MARINØK-1999               Lance
# 14                BIODAFF-1999             Unknown
# 26             Fellestokt-1999           Jan Mayen
# 34                MARINØK-2000               Lance
# 15                BIODAFF-2000             Oceania
# 53             UNIS-AB310-2000           Jan Mayen
# 43                 OAERRE-2000               Lance
# 44                 OAERRE-2001         Håkon Mosby
# 18                Billefjorden                Fram
# 0                          01M         Håkon Mosby
# 19           Billefjorden-2002          Snowmobile
# 45                 OAERRE-2002               Lance
# 32           Kongsfjorden-2002             Oceania
# 54             UNIS-AB310-2002           Jan Mayen
# 49                UNIS-2002-09           Jan Mayen
# 2                       2003UV              Haarek
# 46                     OTI2003           Jan Mayen
# 20               CABANERA-2004           Jan Mayen
# 50                   UNIS-2003           Jan Mayen
# 16                BIODAFF-2003             Oceania
# 3                       2004UV              Haarek
# 47                     OTI2004           Jan Mayen
# 24                   EK60-2004               Lance
# 17                BIODAFF-2004             Oceania
# 51             UNIS-AB202-2004           Jan Mayen
# 55             UNIS-AB320-2004           Jan Mayen
# 21               CABANERA-2005           Jan Mayen
# 25                   EK60-2005               Lance
# 38               MariClim-2006           Jan Mayen
# 39       MariClim-2006-Oceania             Oceania
# 1                        06ABS           Jan Mayen
# 22              Cleopatra-2007  CONVEYANCE-MISSING
# 4   2007-04-EXPEDITION-MISSING  CONVEYANCE-MISSING
# 40               MariClim-2007           Jan Mayen
# 5   2007-05-EXPEDITION-MISSING  CONVEYANCE-MISSING
# {"expedition":"UNIS-AB310-1998","conveyance":"Jan Mayen","programs":["UNIS AB310"],"first_sampling_date":"1998-09-10T12:00:00Z","last_sampling_date":"1998-09-20T12:00:00Z"}
# {"expedition":"MARIN\u00d8K-1999","conveyance":"Lance","programs":["MARIN\u00d8K"],"first_sampling_date":"1999-05-05T03:50:00Z","last_sampling_date":"1999-05-21T20:30:00Z"}
# {"expedition":"BIODAFF-1999","conveyance":"Unknown","programs":["BIODAFF"],"first_sampling_date":"1999-07-01T01:00:00Z","last_sampling_date":"1999-07-01T23:00:00Z"}
# {"expedition":"Fellestokt-1999","conveyance":"Jan Mayen","programs":["Fellestokt"],"first_sampling_date":"1999-09-23T10:33:00Z","last_sampling_date":"1999-10-21T19:15:00Z"}
# {"expedition":"MARIN\u00d8K-2000","conveyance":"Lance","programs":["MARIN\u00d8K"],"first_sampling_date":"2000-03-16T12:25:00Z","last_sampling_date":"2000-03-20T12:55:00Z"}
# {"expedition":"BIODAFF-2000","conveyance":"Oceania","programs":["BIODAFF"],"first_sampling_date":"2000-07-01T00:00:00Z","last_sampling_date":"2000-07-01T07:00:00Z"}
# {"expedition":"UNIS-AB310-2000","conveyance":"Jan Mayen","programs":["UNIS AB310"],"first_sampling_date":"2000-09-22T19:34:00Z","last_sampling_date":"2000-09-24T14:56:00Z"}
# {"expedition":"OAERRE-2000","conveyance":"Lance","programs":["OAERRE"],"first_sampling_date":"2000-12-31T16:58:00Z","last_sampling_date":"2000-12-31T16:58:00Z"}
# {"expedition":"OAERRE-2001","conveyance":"H\u00e5kon Mosby","programs":["OAERRE"],"first_sampling_date":"2001-02-20T10:30:00Z","last_sampling_date":"2001-12-01T12:35:00Z"}
# {"expedition":"Billefjorden","conveyance":"Fram","programs":["Billefjorden"],"first_sampling_date":"2001-03-15T00:00:00Z","last_sampling_date":"2001-09-27T00:00:00Z"}
# {"expedition":"01M","conveyance":"H\u00e5kon Mosby","programs":["BIODAFF"],"first_sampling_date":"2001-05-20T00:00:00Z","last_sampling_date":"2001-09-05T00:00:00Z"}
# {"expedition":"Billefjorden-2002","conveyance":"Snowmobile","programs":["Billefjorden"],"first_sampling_date":"2002-03-21T00:00:00Z","last_sampling_date":"2002-04-25T00:00:00Z"}
# {"expedition":"OAERRE-2002","conveyance":"Lance","programs":["OAERRE"],"first_sampling_date":"2002-04-10T11:07:00Z","last_sampling_date":"2002-04-18T16:37:00Z"}
# {"expedition":"Kongsfjorden-2002","conveyance":"Oceania","programs":["BIODAFF II"],"first_sampling_date":"2002-07-29T07:00:00Z","last_sampling_date":"2002-07-30T21:30:00Z"}
# {"expedition":"UNIS-AB310-2002","conveyance":"Jan Mayen","programs":["UNIS AB310"],"first_sampling_date":"2002-09-11T13:00:00Z","last_sampling_date":"2002-09-20T12:30:00Z"}
# {"expedition":"UNIS-2002-09","conveyance":"Jan Mayen","programs":[],"first_sampling_date":"2002-09-22T06:00:00Z","last_sampling_date":"2002-09-23T02:00:00Z"}
# {"expedition":"2003UV","conveyance":"Haarek","programs":["UV-project"],"first_sampling_date":"2003-04-17T13:40:00Z","last_sampling_date":"2003-07-19T12:00:00Z"}
# {"expedition":"OTI2003","conveyance":"Jan Mayen","programs":["On Thin Ice?"],"first_sampling_date":"2003-05-15T00:00:00Z","last_sampling_date":"2003-12-05T06:58:00Z"}
# {"expedition":"CABANERA-2004","conveyance":"Jan Mayen","programs":["CABANERA"],"first_sampling_date":"2003-07-10T11:00:00Z","last_sampling_date":"2004-08-01T17:00:00Z"}
# {"expedition":"UNIS-2003","conveyance":"Jan Mayen","programs":["UNIS"],"first_sampling_date":"2003-07-13T09:00:00Z","last_sampling_date":"2003-12-08T16:00:00Z"}
# {"expedition":"BIODAFF-2003","conveyance":"Oceania","programs":["BIODAFF"],"first_sampling_date":"2003-08-03T03:00:00Z","last_sampling_date":"2003-08-03T15:30:00Z"}
# {"expedition":"2004UV","conveyance":"Haarek","programs":["UV-project"],"first_sampling_date":"2004-05-08T00:00:00Z","last_sampling_date":"2004-06-08T00:00:00Z"}
# {"expedition":"OTI2004","conveyance":"Jan Mayen","programs":["On Thin Ice?"],"first_sampling_date":"2004-05-24T12:31:00Z","last_sampling_date":"2004-05-30T10:31:00Z"}
# {"expedition":"EK60-2004","conveyance":"Lance","programs":["EK60"],"first_sampling_date":"2004-06-08T05:30:00Z","last_sampling_date":"2004-06-10T21:30:00Z"}
# {"expedition":"BIODAFF-2004","conveyance":"Oceania","programs":["BIODAFF"],"first_sampling_date":"2004-07-21T03:30:00Z","last_sampling_date":"2004-07-21T19:00:00Z"}
# {"expedition":"UNIS-AB202-2004","conveyance":"Jan Mayen","programs":["UNIS AB202"],"first_sampling_date":"2004-08-22T19:30:00Z","last_sampling_date":"2004-08-28T04:30:00Z"}
# {"expedition":"UNIS-AB320-2004","conveyance":"Jan Mayen","programs":["UNIS AB320"],"first_sampling_date":"2004-08-31T01:00:00Z","last_sampling_date":"2004-09-09T03:30:00Z"}
# {"expedition":"CABANERA-2005","conveyance":"Jan Mayen","programs":["CABANERA"],"first_sampling_date":"2005-05-20T14:00:00Z","last_sampling_date":"2005-06-01T11:00:00Z"}
# {"expedition":"EK60-2005","conveyance":"Lance","programs":["EK60"],"first_sampling_date":"2005-06-27T13:25:00Z","last_sampling_date":"2005-06-30T17:30:00Z"}
# {"expedition":"MariClim-2006","conveyance":"Jan Mayen","programs":["MariClim"],"first_sampling_date":"2006-04-25T02:09:00Z","last_sampling_date":"2006-06-08T01:20:00Z"}
# {"expedition":"MariClim-2006-Oceania","conveyance":"Oceania","programs":["MariClim"],"first_sampling_date":"2006-07-27T00:00:00Z","last_sampling_date":"2006-07-28T00:00:00Z"}
# {"expedition":"06ABS","conveyance":"Jan Mayen","programs":["MariClim"],"first_sampling_date":"2006-08-27T04:00:00Z","last_sampling_date":"2006-09-09T02:45:00Z"}
# {"expedition":"Cleopatra-2007","conveyance":"CONVEYANCE-MISSING","programs":["Cleopatra"],"first_sampling_date":"2007-03-06T11:30:00Z","last_sampling_date":"2007-09-04T12:00:00Z"}
# {"expedition":"2007-04-EXPEDITION-MISSING","conveyance":"CONVEYANCE-MISSING","programs":[],"first_sampling_date":"2007-04-19T12:00:00Z","last_sampling_date":"2007-04-19T12:00:00Z"}
# {"expedition":"MariClim-2007","conveyance":"Jan Mayen","programs":["MariClim"],"first_sampling_date":"2007-05-12T07:56:00Z","last_sampling_date":"2007-10-07T17:30:00Z"}
# {"expedition":"2007-05-EXPEDITION-MISSING","conveyance":"CONVEYANCE-MISSING","programs":[],"first_sampling_date":"2007-05-22T12:00:00Z","last_sampling_date":"2007-05-22T12:00:00Z"}
# {"expedition":"NON07","conveyance":"Jan Mayen","programs":[],"first_sampling_date":"2007-07-22T14:00:00Z","last_sampling_date":"2007-10-08T09:30:00Z"}
# {"expedition":"Cleopatra-2008","conveyance":"CCGS Amundsen","programs":["CFL","Cleopatra"],"first_sampling_date":"2008-03-16T00:51:00Z","last_sampling_date":"2008-09-04T13:00:00Z"}
# {"expedition":"MariClim-2008","conveyance":"Jan Mayen","programs":["MariClim"],"first_sampling_date":"2008-04-16T19:25:00Z","last_sampling_date":"2008-07-23T09:02:00Z"}
# {"expedition":"2008-08-EXPEDITION-MISSING","conveyance":"CONVEYANCE-MISSING","programs":[],"first_sampling_date":"2008-08-21T12:00:00Z","last_sampling_date":"2008-08-23T12:00:00Z"}
# {"expedition":"MERCLIM-2009","conveyance":"G.O. Sars","programs":["Alkekonge","MOSJ","MERCLIM"],"first_sampling_date":"2009-06-15T02:45:00Z","last_sampling_date":"2009-06-22T13:00:00Z"}
# {"expedition":"Alkekonge-2009","conveyance":"Lance","programs":["Alkekonge","MOSJ"],"first_sampling_date":"2009-07-17T00:00:00Z","last_sampling_date":"2009-07-22T20:10:00Z"}
# {"expedition":"SANA09","conveyance":"Viking Explorer","programs":[],"first_sampling_date":"2009-07-21T12:00:00Z","last_sampling_date":"2009-07-27T12:00:00Z"}
# {"expedition":"Alkekonge-2009b","conveyance":"Viking Explorer","programs":["Alkekonge","MOSJ"],"first_sampling_date":"2009-07-21T15:15:00Z","last_sampling_date":"2009-07-28T15:05:00Z"}
# {"expedition":"Alkekonge-2010","conveyance":"Lance","programs":["Alkekonge","MOSJ"],"first_sampling_date":"2010-07-17T12:50:00Z","last_sampling_date":"2010-07-26T04:40:00Z"}
# {"expedition":"ICE2010","conveyance":"Lance","programs":["ICE ECO"],"first_sampling_date":"2010-08-17T22:25:00Z","last_sampling_date":"2010-08-30T08:00:00Z"}
# {"expedition":"ICE2011","conveyance":"Lance","programs":["ICE ECO"],"first_sampling_date":"2011-04-27T20:38:00Z","last_sampling_date":"2011-05-14T04:20:00Z"}
# {"expedition":"2011-04-EXPEDITION-MISSING","conveyance":"Lance","programs":["ICE ECO"],"first_sampling_date":"2011-04-29T15:00:00Z","last_sampling_date":"2011-04-29T15:00:00Z"}
# {"expedition":"MOSJ2012","conveyance":"Lance","programs":["MOSJ"],"first_sampling_date":"2011-07-13T14:00:00Z","last_sampling_date":"2012-07-21T11:00:00Z"}
# {"expedition":"ICE2012","conveyance":"Lance","programs":["ICE"],"first_sampling_date":"2011-07-26T20:30:00Z","last_sampling_date":"2013-07-30T07:59:59Z"}
# {"expedition":"2012-01-EXPEDITION-MISSING","conveyance":"Helmer Hanssen","programs":["BIO-8510 ARCTOS"],"first_sampling_date":"2012-01-12T02:28:00Z","last_sampling_date":"2012-01-18T21:42:59Z"}
# {"expedition":"MOSJ2013","conveyance":"Lance","programs":["ICE ECO"],"first_sampling_date":"2013-07-23T00:00:00Z","last_sampling_date":"2017-02-16T00:00:00Z"}
